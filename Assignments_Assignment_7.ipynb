# %% [markdown]
# #Practice
# ##1.Load example.csv and consider ' ','N/A', and '미공개' as NA values

# %%
import pandas as pd

# %%
df=pd.read_csv("example.csv",encoding='cp949',na_values=['', 'N/A', '미공개'])
df
# Out:
#     이름  나이  소득(만원)    재산(만원)
# 0  김철수  17    2000       NaN
# 1  김안나  65   12000       NaN
# 2  장재연  42    3000       NaN
# 3  최진만  14    5600  100000.0
# 4  박형구  27     900   30000.0

# %% [markdown]
# ##2. Replace NaN with 10000 (you can use fillna method)

# %%
df.fillna(10000,inplace=True)
df
# Out:
#     이름  나이  소득(만원)    재산(만원)
# 0  김철수  17    2000   10000.0
# 1  김안나  65   12000   10000.0
# 2  장재연  42    3000   10000.0
# 3  최진만  14    5600  100000.0
# 4  박형구  27     900   30000.0

# %% [markdown]
# ##3. Set 이름 column as index (이름 should be the name of index)

# %%
df=df.set_index(keys='이름')
df
# Out:
#      나이  소득(만원)    재산(만원)
# 이름
# 김철수  17    2000   10000.0
# 김안나  65   12000   10000.0
# 장재연  42    3000   10000.0
# 최진만  14    5600  100000.0
# 박형구  27     900   30000.0

# %% [markdown]
# ##4. Add a column of 성별 as follows

# %%
gender = ['남','여','남','남','남']
df['성별'] = gender
df
# Out:
#      나이  소득(만원)    재산(만원) 성별
# 이름
# 김철수  17    2000   10000.0  남
# 김안나  65   12000   10000.0  여
# 장재연  42    3000   10000.0  남
# 최진만  14    5600  100000.0  남
# 박형구  27     900   30000.0  남
